# %%
from test import *
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Remove Non-relevant Reviews Classification

# %%
run_all(cross_val=3, 
        analyze_metrics=True, 
        confusion_matrix=True, 
        parser=parse_csv_discard_non_relevant)
# Out:
# 0.7127192982456141
# SGD [0.71710526 0.70892829 0.71710526 0.72386961]
# LSVC [0.69736842 0.69456797 0.69736842 0.6983358 ]
# CNB [0.72149123 0.71929883 0.72149123 0.73382303] LR [0.67324561 0.6603072  0.67324561 0.68197093]

# %% [markdown]
# # Relevant vs Non-relevant Classification

# %%
run_all(cross_val=10, 
        analyze_metrics=True, 
        confusion_matrix=True, 
        parser=parse_csv_relevant_non_relevant)

# %% [markdown]
# # Basic Classification

# %%
run_all(cross_val=10, 
        analyze_metrics=True, 
        confusion_matrix=True, 
        parser=parse_csv_remove_multiclass)

# %% [markdown]
# # Multilayered Classification

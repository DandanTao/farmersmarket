# %%
from test import *
# %matplotlib inline

# %%
# Out:
# 0
# [0.58706468 0.57823933 0.58706468 0.61552433]
# [0.48258706 0.65100671 0.48258706 0.48258706]
# [0.64676617 0.6392502  0.64676617 0.65563452]
# [0.51741294 0.48043218 0.51741294 0.63554217]
# [0.57711443 0.55903826 0.57711443 0.59096956]
# [0.52736318 0.49454591 0.52736318 0.61645732]

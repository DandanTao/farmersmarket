# %%
from test import *
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
run_all(cross_val=2, plot=True, confusion_matrix=True)
# Out:
# 0
# [0.5670103092783505, 0.5545255037167448, 0.5670103092783505, 0.5595026350461133]
# [0.5051546391752577, 0.6712328767123288, 0.5051546391752577, 0.5051546391752577]
# [0.6391752577319587, 0.6282110978740192, 0.6391752577319587, 0.6345130412670735]
# [0.5412371134020618, 0.46821171243752197, 0.5412371134020618, 0.7272414547956344]
# [0.5360824742268041, 0.510348705671893, 0.5360824742268041, 0.5023481089590308]
# [0.5360824742268041, 0.4160634007884867, 0.5360824742268041, 0.5719057324016563]

# %%
import string
import spacy
from copy import deepcopy as DP

from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import ComplementNB
from sklearn.naive_bayes import BernoulliNB
from sklearn.svm import SVC
from sklearn.svm import LinearSVC
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import SGDClassifier

from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.base import TransformerMixin
from sklearn.feature_extraction.stop_words import ENGLISH_STOP_WORDS as stopwords
from sklearn.model_selection import train_test_split

import numpy as np

punctuations = string.punctuation
parser = spacy.load('en')

def parse_csv0(file):
    """
    reads csv file data with labels and comment
    """
    import pandas as pd
    df = pd.read_csv(file)

    df.drop(["Index", "Unnamed: 5", "Notes", "Words"], axis=1, inplace=True)
    df=df.fillna("Non-relevant")

    for index, row in df.iterrows():
        if row['Label'] != 'Non-relevant':
            row['Label'] = 'relevant'
    
    print(df)
    train, test = train_test_split(df, test_size=0.2)
    return train.to_numpy(), test.to_numpy()

def parse_csv1(file):
    """
    reads csv file data with labels and comment
    """
    import pandas as pd
    df = pd.read_csv(file)

    df.drop(["Index", "Unnamed: 5", "Notes", "Words"], axis=1, inplace=True)
    df=df.fillna("None")

    # drop all sentence with multiple labels
    df=df[~df.Label.str.contains(",")]

    # drop all sentences with label 'covinience'
    # df = df.replace('covinience', 'convenience')
    df = df[df.Label != 'covinience']
    df = df[df.Label != 'safety']

    train, test = train_test_split(df, test_size=0.2)
    return train.to_numpy(), test.to_numpy()

train, test = parse_csv("../data/yelp_labelling_1000.csv")
# Out:
#                                               Sentences         Label
# 0     I would definitely want to come back here when...      relevant
# 1     Haven't seen one in a long time though, person...  Non-relevant
# 2     River Valley is a premium grower ("using organ...      relevant
# 3     Today there was a group of belly dancers perfo...      relevant
# 4     I mean, I am not the folks from Portlandia, (h...      relevant
# 5     It's great to check out all the local vendors ...      relevant
# 6      Hint, move it to an area that is not so crowded.      relevant
# 7                                                  Yum!      relevant
# 8     The Willis Farmer's Market is on Thursdays in ...  Non-relevant
# 9     I really enjoyed the spinach artichoke dip, ap...      relevant
# 10    I volunteered at a booth here and people are v...      relevant
# 11    I work with the Urbana Farmers Market and I LO...  Non-relevant
# 12    An organic tomato farm sells wonderful salsas ...      relevant
# 13                                          Good stuff.      relevant
# 14    The streets were not even marked clearly and o...      relevant
# 15               This is just one of those "eh" places.      relevant
# 16       Sweet family owned farm in northwest Illinois.      relevant
# 17                             Only one organic vendor.      relevant
# 18    Much bigger than I thought it would be and I l...      relevant
# 19    I did not see any already butchered whole chic...      relevant
# 20    It has ice cream and has Easter brunch is best...      relevant
# 21    It's way, way too crowded for the amount of ve...      relevant
# 22    It is a pretty stable group of vendors, that i...      relevant
# 23    Awesome things: Ozark Forest Mushrooms - Black...      relevant
# 24    You can definitely tell what is up when your f...      relevant
# 25                     This is such a cute little farm!      relevant
# 26    You could do most of your shopping for the wee...      relevant
# 27    I love farmer's markets, but I especially love...      relevant
# 28                      A fun way to start the weekend.      relevant
# 29    Whether you live or work in this community or ...      relevant
# ...                                                 ...           ...
# 971   The owner also supports local schools through ...      relevant
# 972                         Fresh ones last longer. ;-)      relevant
# 973    I found this strange, but that could just be me.  Non-relevant
# 974   I left, very disappointed will return, but wil...      relevant
# 975   They nowhere near represent the array of Vietn...  Non-relevant
# 976   And when we moved from the tomato area she too...      relevant
# 977   Last Saturday, I was in Terre Haute (don't bot...  Non-relevant
# 978   Another reason to love Wisconsin and relish in...  Non-relevant
# 979                     Very handy to the neighborhood.      relevant
# 980                    And, the owners are super sweet.      relevant
# 981   The line might look long and deceiving but it ...      relevant
# 982   Yes and yes...with only one trip, the Ferguson...  Non-relevant
# 983   We look forward to our Saturday mornings and e...  Non-relevant
# 984            NOTE: Good amount of stairs up and down.  Non-relevant
# 985   Plenty of fresh locally grown organic fruits, ...      relevant
# 986         It shoots a pumpkin every hour on the hour.      relevant
# 987                      Anyways, all I can say is UGH!  Non-relevant
# 988   The heirloom tomatoes are at the end of their ...      relevant
# 989   Stop by and see Mike from Churchhill Orchards ...      relevant
# 990                          It seems like you are not.  Non-relevant
# 991   They have all the fresh fruits and vegetables ...      relevant
# 992   There are lots of vendors for fresh fruits and...      relevant
# 993                The night market was fun but busy...      relevant
# 994              Just raised $65k for decor/renovation.  Non-relevant
# 995   Homemade jelly, butter and organic milk are aw...      relevant
# 996   I made dill pickles and mixed vegetable pickle...      relevant
# 997              They're the BEST danishes in the city!  Non-relevant
# 998   To know that I saw the animal alive and breath...      relevant
# 999   Something to note: I believe they do not allow...      relevant
# 1000  Generally speaking even though this is not an ...      relevant
#
# [1001 rows x 2 columns]
